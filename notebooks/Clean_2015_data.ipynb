# %% [markdown]
# # Settings

# %%
import numpy as np
import pandas as pd

pd.set_option('max.colwidth', 500)

# %%
# %reload_ext rpy2.ipython

# %% [markdown]
# # Scraping scripts

# %% [markdown]
# ## Titles only

# %% [raw]
# import scrapy
# from scrapy.crawler import CrawlerProcess
# from scrapy.utils.log import configure_logging
# import logging
#
#
# class Article(scrapy.Item):
#     article = scrapy.Field()
#     articleURL = scrapy.Field()
#
#
# logger = logging.getLogger('testlogger')
#
#
# class IntroSpider(scrapy.Spider):
#     name = "intro_spider"  # Name of the scraper
#
#     configure_logging(install_root_handler=False)
#     logging.basicConfig(
#         filename='/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/medium_titles_2015_log.txt',
#         format='%(levelname)s: %(message)s',
#         level=logging.INFO
#     )
#
#     custom_settings = {
#         'FEED_FORMAT': 'csv',
#         'FEED_URI': '/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/medium_titles_2015.csv',
#         'AUTOTHROTTLE_ENABLED': True,
#         'AUTOTHROTTLE_START_DELAY': 1,
#         'AUTOTHROTTLE_MAX_DELAY': 3
#     }
#
#     def start_requests(self):
#         urls = []
#
#         for month in range(1, 13):
#             for day in range(1, 32):
#                 urls.append(f"https://medium.com/tag/data-science/archive/2015/{month:02}/{day:02}")
#
#         for url in urls:
#             yield scrapy.Request(url=url, callback=self.parse)
#
#
#
#     def parse(self, response):
#         for story in response.css('div.postArticle'):
#             yield {
#                 'article': story.css(
#                     'div.postArticle-content section div.section-content div h3::text').getall(),
#                 'articleURL': story.css('div.postArticle-readMore a::attr(href)').extract_first(),
#             }
#
#
# process = CrawlerProcess({
#     'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
# })
#
# process.crawl(IntroSpider)
# process.start()

# %% [markdown]
# ## Full article info

# %% [raw]
# import scrapy
# from scrapy.crawler import CrawlerProcess
# from scrapy.utils.log import configure_logging
# import logging
#
# import os
# os.chdir('/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/')
#
# class Article(scrapy.Item):
#     nameOfAuthor = scrapy.Field()
#     linkOfAuthorProfile = scrapy.Field()
#     NumOfComments = scrapy.Field()
#     article = scrapy.Field()
#     postingTime = scrapy.Field()
#     NumOfClaps = scrapy.Field()
#     articleURL = scrapy.Field()
#     articleTags = scrapy.Field()
#     readingTime = scrapy.Field()
#
# logger = logging.getLogger('testlogger')
#
#
# class IntroSpider(scrapy.Spider):
#     name = "intro_spider"
#
#
#     configure_logging(install_root_handler=False)
#     logging.basicConfig(
#         filename='medium_full_2015_log.txt',
#         format='%(levelname)s: %(message)s',
#         level=logging.INFO
#     )
#
#     custom_settings = {
#         'FEED_FORMAT': 'csv',
#         'FEED_URI': 'medium_full_2015.csv',
#         'AUTOTHROTTLE_ENABLED' : True,
#         'AUTOTHROTTLE_START_DELAY' : 1,
#         'AUTOTHROTTLE_MAX_DELAY' : 3
#     }
#
#
#     def start_requests(self):
#         urls = []
#
#         for month in range(1, 13):
#             for day in range(1, 32):
#                 urls.append(f"https://medium.com/tag/data-science/archive/2015/{month:02}/{day:02}")
#
#         for url in urls:
#             yield scrapy.Request(url=url, callback=self.parse)
#
#
#
#     def parse(self, response):
#         item = Article()
#
#         for story in response.css('div.postArticle'):
#             if story.css('div.postArticle-readMore a::attr(href)').extract_first() is not None:
#                 url = story.css('div.postArticle-readMore a::attr(href)').extract_first()
#                 yield scrapy.Request(url=url, callback=self.parse_tags, meta={'item': item})
#
#     def parse_tags(self, response):
#
#         item = response.meta['item']
#         item['articleURL'] = response.request.url
#         item['article'] = response.css('div.postArticle-content section div.section-content div h1::text, \
#                                         div.postArticle-content section div.section-content div h1 a::text, \
#                                         div.postArticle-content section div.section-content div h1 strong::text,\
#                                         div.postArticle-content section div.section-content div h1 em::text, \
#                                         div.postArticle-content section div.section-content div h3::text, \
#                                         div.postArticle-content section div.section-content div h4::text, \
#                                         div.postArticle-content section div.section-content div p strong::text, \
#                                         div.postArticle-content section div.section-content div p strong em::text, \
#                                         div.postArticle-content section div.section-content div p::text').extract_first()
#
#
#         #item['article'] = response.xpath('//div/main/article/div/section/div[2]/div/h1//text() | //div/main/article/div/section/div[2]/div/h4//text() | //div/main/article/div/section/div[2]/div/h1/a//text() | //div/main/article/div/section/div[2]/div/h1/strong//text() | //div/main/article/div/section/div[2]/div/h1/em//text() | //div/main/article/div/section/div[2]/div/p//text()').extract_first()
#
#
#
#
#         try:
#             item['linkOfAuthorProfile'] = response.css('div.u-paddingBottom3 a').attrib['href']
#         except KeyError:
#             item['linkOfAuthorProfile'] = ' '
#
#         try:
#             item['readingTime'] = response.css('span.readingTime').attrib['title']
#         except KeyError:
#             item['readingTime'] = ' '
#
#
#         item['nameOfAuthor'] = response.css('div.u-paddingBottom3 a::text').extract_first()
#         item['postingTime'] = response.css('time::text').extract_first()
#         item['articleTags'] = response.css('div.u-paddingBottom10 ul.tags--postTags li a::text').getall()
#         item['NumOfComments'] = response.css(
#             'div.buttonSet.u-flex0 button.button.button--chromeless.u-baseColor--buttonNormal.u-marginRight12::text').extract_first()
#         item['NumOfClaps'] = response.xpath(
#             '//div/main/article/footer/div[1]/div[3]/div/div[1]/div/span/button//text()').extract_first()
#
#
#         yield item
#
#
# process = CrawlerProcess({
#     'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
# })
#
# process.crawl(IntroSpider)
# process.start()

# %% [markdown]
# # Import data

# %%
titles = pd.read_csv("/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/medium_titles_2015.csv")

full = pd.read_csv("/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/medium_full_2015.csv")

# %%
print("Full:", full.shape)
print("Titles:", titles.shape)
# Out:
# Full: (1125, 9)
# Titles: (1276, 2)

# %% [markdown]
# # Clean URL in full article data table

# %%
full['articleLink'] = full['articleURL'].str.split('?').str[0]

full.drop('articleURL', axis=1, inplace=True)

full.drop_duplicates(subset=['articleLink'], keep='first', inplace=True)

print(full.shape)
# Out:
# (1030, 9)

# %% [markdown]
# # Clean URL in titles data table

# %%
titles['articleLink'] = titles['articleURL'].str.split('?').str[0]

titles.drop('articleURL', axis=1, inplace=True)

titles.drop_duplicates(subset=['articleLink'], keep='first', inplace=True)

print(titles.shape)
# Out:
# (1049, 2)

# %% [markdown]
# # Merge two data tables to get full set of links

# %%
merged = full.merge(titles, how='outer', left_on='articleLink', right_on='articleLink' )

merged.drop(['article_x', 'article_y'], axis=1, inplace=True)

# %% [markdown]
# # Analyze titles

# %% [markdown]
# ## Parse URL slugs for title

# %%
## Remove NULLs in articleLink column 
merged.dropna(subset=['articleLink'], inplace=True)

# %%
for index, row in merged.iterrows():
    for link in row['articleLink'].split('/'):
        if '-' in link:
            words = link.split('-')[:-1]
            merged.loc[index, 'names'] = ' '.join(words)

# %%
## Remove NULLs in parsed article title column 
merged.dropna(subset=['names'], inplace=True)

# %% [markdown]
# ## POS analysis

# %%
from textblob import TextBlob
from collections import Counter

def textblob_adj(text):
    blobed = TextBlob(text)
    counts = Counter(tag for word,tag in blobed.tags)
    
    adj_list = []
    adv_list = []
    noun_list = []
    pron_list = []
    verb_list = []
    
    adj_tag_list = ['JJ','JJR','JJS']
    adv_tag_list = ['RB','RBR','RBS','WRB']
    noun_tag_list = ['NN','NNS','NNP','NNPS']
    pron_tag_list = ['PRP','PRP$','WP','WP$']
    verb_tag_list = ['VB','VBD','VBG','VBN','VBP','VBZ']
        
    for (a, b) in blobed.tags:
        if b in adj_tag_list:
           adj_list.append(a)
        elif b in adv_tag_list:
           adv_list.append(a)
        elif b in noun_tag_list:
            noun_list.append(a)
        elif b in pron_tag_list:
            pron_list.append(a)
        elif b in verb_tag_list:
            verb_list.append(a)
        else:
            pass
        
    return adj_list, adv_list, noun_list, pron_list, verb_list, counts['JJ']+counts['JJR']+counts['JJS'],  counts['RB']+counts['RBR']+counts['RBS']


adj_list = []

adv_list = []

noun_list = []

pron_list = []

verb_list = []


for sent in merged["names"]:
    adj, adv, noun, pron, verb, adj_count, adv_count = textblob_adj(sent)
    
    if adj:
        adj_list.append(adj)
    else:
        pass
    
    
    if adv:
        adv_list.append(adv)
    else:
        pass
    
    
    if noun:
        noun_list.append(noun)
    else:
        pass
    
    if pron:
        pron_list.append(pron)
    else:
        pass
    
    if verb:
        verb_list.append(verb)
    else:
        pass

# %%
word_list = []

for x in adj_list:
    for y in x:
        word_list.append(y)
        
from collections import Counter
counts = Counter(word_list)
print(counts)
# Out:
# Counter({'big': 95, 'new': 20, 'predictive': 18, 'programmable': 13, 'great': 12, 's': 11, 'i': 11, 'good': 11, 'deep': 9, 'real': 9, 'social': 8, 'first': 8, 'next': 8, 'online': 7, 'better': 7, 'tutorial': 7, 'uoptutorial': 7, 'top': 6, 'open': 6, 'right': 6, 'linear': 5, 'unstructured': 5, 'human': 5, 'important': 5, 'black': 5, 'quick': 5, 'other': 5, 'small': 5, 'best': 4, 'statistical': 4, 'simple': 4, 'much': 4, 'san': 4, 'u': 4, 'spark': 4, 'bad': 4, 'white': 3, 'critical': 3, 'modern': 3, 'interactive': 3, 'smarter': 3, 'airbnb': 3, 'random': 3, 'insight': 3, 'smart': 3, 'amazon': 3, 'visual': 3, 'large': 3, 'worth': 3, 'biggest': 3, 'wrong': 3, 'digital': 3, 'cognitive': 3, 'nlp': 3, 'uop': 3, 'more': 3, 'many': 3, 'text': 3, 'easy': 3, 'essential': 3, 'own': 3, 'common': 3, 'logistic': 2, 'bayesian': 2, 'single': 2, 'exciting': 2, 'por': 2, 'personal': 2, 'successful': 2, 'analytical': 2, 'predictable': 2, 'interesting': 2, 'chart': 2, 'impactful': 2, 'useful': 2, 'beautiful': 2, 'able': 2, 'little': 2, 'risky': 2, 'nice': 2, 'anomaly': 2, 'polar': 2, 'aclima': 2, 'senior': 2, 'mechanical': 2, 'invisible': 2, 'hard': 2, 'sexy': 2, 'excellent': 2, 'true': 2, 'content': 2, 'environmental': 2, 'past': 2, 'data': 2, 'website': 2, 'neural': 2, 'practical': 2, 'forest': 2, 'london': 2, 'effective': 2, 'technical': 2, 'scientific': 2, 'initial': 2, 'belong': 2, 'key': 2, 'automatic': 2, 'long': 2, 'swedish': 2, 'popular': 2, 'upworthy': 2, 'advanced': 2, 'basic': 2, 'industrial': 2, 'prescriptive': 1, 'creative': 1, 'complex': 1, 'american': 1, 'red': 1, 'chinese': 1, 'outlier': 1, 'c': 1, 'strategic': 1, 'polynomial': 1, 'gaussian': 1, 'exponential': 1, 'transactional': 1, 'titanic': 1, 'datenanalyse': 1, 'uninitiated': 1, 'duplicate': 1, 'reactive': 1, 'stitch': 1, 'ncaa': 1, 'elite': 1, 'b': 1, 'zendrive': 1, 'final': 1, 'ahas': 1, 'o': 1, 'international': 1, 'instacart': 1, '21st': 1, 'swish': 1, 'hot': 1, 'berkeley': 1, 'crowdsourced': 1, 'present': 1, 'future': 1, 'noaas': 1, 'gremthon': 1, 'parallel': 1, 'magic': 1, 'sneak': 1, 'public': 1, 'irish': 1, 'scale': 1, 'whole': 1, 'ssystematic': 1, 'user': 1, 'street': 1, 'crm': 1, '14th': 1, 'happy': 1, '10th': 1, 'last': 1, 'fm': 1, 'infectious': 1, 'different': 1, 'unreasonable': 1, 'grid': 1, 'plain': 1, 'stupid': 1, 'french': 1, 'node': 1, 'complete': 1, 'las': 1, 'abandono': 1, 'national': 1, 'nsfw': 1, 'mobile': 1, 'nascent': 1, 'umair': 1, 'definitive': 1, 'chris': 1, 'froome': 1, 'perspective': 1, 'nasa': 1, 'special': 1, 'nyc': 1, 'sql': 1, 'outdoor': 1, 'transformational': 1, 'disruptive': 1, 'transporte': 1, 'recursive': 1, 'ds': 1, 'same': 1, 'younger': 1, 'negative': 1, 'nitronaut': 1, 'com': 1, 'svm': 1, 'binary': 1, 'fastest': 1, 'anomalous': 1, 'flawless': 1, 'excited': 1, 'tech': 1, 'weird': 1, 'i3': 1, 'ntt': 1, 'intern': 1, 'dismal': 1, 'hottest': 1, 'fresh': 1, 'diagnostic': 1, 'robust': 1, 'principal': 1, 'proteus': 1, 'fast': 1, 'lmm': 1, 'intracol': 1, 'spatial': 1, 'stratified': 1, 'seus': 1, 'mental': 1, 'ml': 1, 'el': 1, 'saturday': 1, 'insightful': 1, 'tastic': 1, 'dont': 1, 'old': 1, 'ubiquitous': 1, 'choose': 1, 'cheap': 1, 'whacky': 1, 'habit': 1, 'retail': 1, 'perfect': 1, 'icml': 1, 'potential': 1, 'dataflow': 1, 'high': 1, 'slanting': 1, 'disciplinary': 1, 'um': 1, 'corporate': 1, 'political': 1, 'isn': 1, 'shaped': 1, 'dangerous': 1, 'professor': 1, 'use': 1, 'bigobject': 1, 'threshold': 1, 'usando': 1, 'rapid': 1, 'start': 1, 'hillary': 1, 'presidential': 1, 'bay': 1, 'alexandra': 1, 'probablistic': 1, 'optimal': 1, 'indian': 1, 'ethical': 1, 'safe': 1, 'civil': 1, 'generic': 1, 'svg': 1, 'computational': 1, 'differential': 1, 'sxsw': 1, 'siloed': 1, 'und': 1, 'auch': 1, 'historic': 1, 'wireless': 1, 'lake': 1, 'underwater': 1, 'andrea': 1, 'api': 1, 'uncomfortable': 1, 'r': 1, 'unknown': 1, 'sure': 1, 'metric': 1, 'greatest': 1, 'haz': 1, 'india': 1, 'audacious': 1, 'uma': 1, 'geral': 1, 'liberal': 1, 'closer': 1, 'f': 1, 'iq': 1, 'nf ...

# %%
import numpy as np
import random
from matplotlib import pyplot as plt

data = num_adv 

bins = 10

# fixed bin size
plt.xlim([min(data)-5, max(data)+5])


plt.hist(data, bins=bins, alpha=0.5)
plt.title('Random Gaussian data (fixed bin size)')
plt.xlabel('variable X (bin size = 5)')
plt.ylabel('count')

plt.show()

# %% [markdown]
# ## Title bigram relationships

# %% [markdown]
# ### Get title bigrams counts

# %%
## Remove NULLs in parsed article title column 
merged.dropna(subset=['names'], inplace=True)

# %%
import collections
import nltk

import spacy
from spacy_langdetect import LanguageDetector

nlp = spacy.load('en_core_web_sm')

nlp.add_pipe(LanguageDetector(), name="language_detector", last=True)

counts = collections.Counter()

for sent in merged["names"]:
    doc = nlp(sent)
    test1 = []
    if doc._.language['language'] == 'en':
        for token in doc:
            if token.is_alpha:
                test1.append(token.text.lower())
    counts.update(nltk.bigrams(test1))

# %%
bigram_counts = pd.DataFrame.from_dict(counts, orient='index').reset_index()

bigram_counts.columns = ["Bigrams", 'Count']

bigram_counts[['Term1', 'Term2']] = pd.DataFrame(bigram_counts['Bigrams'].tolist(), index=bigram_counts.index)

# %%
bigram_counts = bigram_counts[['Term1', 'Term2', 'Count']]

bigram_counts.columns = ['word1', 'word2', 'n']

bigram_counts.sort_values(by='n', ascending=False)
# Out:
#              word1          word2   n
# 84            data        science  79
# 130            big           data  61
# 41         machine       learning  41
# 122            how             to  28
# 125           data      scientist  26
# 138             in            the  26
# 141           data     scientists  21
# 21             the           data  21
# 742             of           data  18
# 193              a           data  18
# 35              of            the  15
# 952            and           more  13
# 1000        apache          spark  13
# 27            data       analysis  13
# 954            the   programmable  12
# 953           more             in  11
# 570             to             be  11
# 405        science            and  10
# 955   programmable        edition  10
# 384             to            the  10
# 39          future             of   9
# 112           with           data   9
# 930            and            the   9
# 232     predictive      analytics   9
# 330            for           data   9
# 239            for            the   9
# 92            what             is   8
# 544           data      analytics   8
# 166             in              a   8
# 672             is            the   8
# ...            ...            ...  ..
# 1620           the           loop   1
# 1619       closing            the   1
# 1602      analysis             in   1
# 1581    exhaustion          index   1
# 1582        mental     gymnastics   1
# 1583    gymnastics            for   1
# 1584           for         online   1
# 1585        online      marketers   1
# 1586     marketers    calculating   1
# 1587   calculating         return   1
# 1588        return             on   1
# 1589            on             ad   1
# 1590            ad          spend   1
# 1600            ml           cont   1
# 1601          cont              d   1
# 1603            in  environmental   1
# 1618           api      sleuthing   1
# 1605           the     hypothesis   1
# 1606           kit        revised   1
# 1608     hackathon       datameet   1
# 1609      datameet         mumbai   1
# 1610         where             is   1
# 1611            is             el   1
# 1612            el          chapo   1
# 1613         chapo           some   1
# 1614          some       saturday   1
# 1615      saturday        morning   1
# 1616       morning        twitter   1
# 1617       twitter            api   1
# 4317            in         gensim   1
#
# [4318 rows x 3 columns]

# %%
bigram_counts.to_csv("/Users/nancy/PycharmProjects/medium-ds-articles/data/processed/2015_title_bigram_counts.csv", 
                     index=False)

# %% [markdown]
# ### Visualize bigram relationships

# %%
# %reload_ext rpy2.ipython

# %%
# %%R
#
# library(igraph)
#
# bigram_counts <- read.csv("/Users/nancy/PycharmProjects/medium-ds-articles/data/processed/2015_title_bigram_counts.csv")
#
# #bigram_counts <- head(bigram_counts[order(-bigram_counts$n),], 0.02*nrow(bigram_counts))
#
# bigram_counts <- head(bigram_counts[order(-bigram_counts$n),], 60)
#
# bigram_graph <- bigram_counts %>%
#   graph_from_data_frame()

# %%
# %R bigram_counts
# Out:
#              word1         word2   n
# 85            data       science  79
# 131            big          data  61
# 42         machine      learning  41
# 123            how            to  28
# 126           data     scientist  26
# 139             in           the  26
# 22             the          data  21
# 142           data    scientists  21
# 194              a          data  18
# 743             of          data  18
# 36              of           the  15
# 28            data      analysis  13
# 953            and          more  13
# 1001        apache         spark  13
# 955            the  programmable  12
# 571             to            be  11
# 954           more            in  11
# 385             to           the  10
# 406        science           and  10
# 956   programmable       edition  10
# 40          future            of   9
# 113           with          data   9
# 233     predictive     analytics   9
# 240            for           the   9
# 331            for          data   9
# 931            and           the   9
# 2        analytics           and   8
# 93            what            is   8
# 167             in             a   8
# 545           data     analytics   8
# 553             in          data   8
# 673             is           the   8
# 930           data           and   8
# 1360           why             i   8
# 99            what             s   7
# 159             is             a   7
# 166           data            in   7
# 356            you        should   7
# 373             as             a   7
# 756           data            is   7
# 1095            in        python   7
# 1425          what            do   7
# 1438            to          data   7
# 1642           and           why   7
# 1761          deep      learning   7
# 39             the        future   6
# 58        business  intelligence   6
# 70              at           the   6
# 79             you           can   6
# 132           data            to   6
# 277            the           new   6
# 306            the         first   6
# 358             be             a   6
# 962             of             a   6
# 1014          data        driven   6
# 1132          data           the   6
# 1158             i             m   6
# 1228            to          make   6
# 1382          this            is   6
# 1456            of           big   6

# %%
# %%R -w 800 -h 600
#
# library(ggraph)
#
# set.seed(2016)
#
# a <- grid::arrow(type = "closed")
#
# options(repr.plot.width=12, repr.plot.height=8)
#
# ggraph(bigram_graph, layout = "fr") +
#   geom_edge_link(aes(edge_alpha = n), show.legend = FALSE,
#                  arrow = a, end_cap = circle(.07, 'inches')) +
#   geom_node_point(color = "lightblue", size = 5) +
#   geom_node_text(aes(label = name), vjust = 1, hjust = 1) +
#   theme_void()

# %% [markdown]
# # Association rule analysis of tags

# %%
urls_missing_tags = merged[merged['articleTags'].isnull()]

urls_missing_tags
# Out:
#      NumOfClaps  NumOfComments articleTags linkOfAuthorProfile nameOfAuthor  \
# 337         NaN            NaN         NaN                              NaN
# 1633        NaN            NaN         NaN                              NaN
# 2366        NaN            NaN         NaN                              NaN
# 2666        NaN            NaN         NaN                              NaN
# 3781        NaN            NaN         NaN                              NaN
# 4725        NaN            NaN         NaN                 NaN          NaN
# 4727        NaN            NaN         NaN                 NaN          NaN
# 4728        NaN            NaN         NaN                 NaN          NaN
# 4729        NaN            NaN         NaN                 NaN          NaN
# 4730        NaN            NaN         NaN                 NaN          NaN
# 4731        NaN            NaN         NaN                 NaN          NaN
# 4732        NaN            NaN         NaN                 NaN          NaN
# 4733        NaN            NaN         NaN                 NaN          NaN
# 4734        NaN            NaN         NaN                 NaN          NaN
# 4735        NaN            NaN         NaN                 NaN          NaN
# 4736        NaN            NaN         NaN                 NaN          NaN
# 4737        NaN            NaN         NaN                 NaN          NaN
# 4738        NaN            NaN         NaN                 NaN          NaN
# 4739        NaN            NaN         NaN                 NaN          NaN
# 4740        NaN            NaN         NaN                 NaN          NaN
# 4741        NaN            NaN         NaN                 NaN          NaN
# 4742        NaN            NaN         NaN                 NaN          NaN
# 4743        NaN            NaN         NaN                 NaN          NaN
# 4744        NaN            NaN         NaN                 NaN          NaN
# 4745        NaN            NaN         NaN                 NaN          NaN
# 4746        NaN            NaN         NaN                 NaN          NaN
# 4747        NaN            NaN         NaN                 NaN          NaN
# 4748        NaN            NaN         NaN                 NaN          NaN
# 4749        NaN            NaN         NaN                 NaN          NaN
# 4750        NaN            NaN         NaN                 NaN          NaN
# 4751        NaN            NaN         NaN                 NaN          NaN
# 4752        NaN            NaN         NaN                 NaN          NaN
# 4753        NaN            NaN         NaN                 NaN          NaN
# 4754        NaN            NaN         NaN                 NaN          NaN
# 4755        NaN            NaN         NaN                 NaN          NaN
# 4756        NaN            NaN         NaN                 NaN          NaN
# 4757        NaN            NaN         NaN                 NaN          NaN
# 4758        NaN            NaN         NaN                 NaN          NaN
# 4759        NaN            NaN         NaN                 NaN          NaN
# 4760        NaN            NaN         NaN                 NaN          NaN
# 4761        NaN            NaN         NaN                 NaN          NaN
# 4762        NaN            NaN         NaN                 NaN          NaN
# 4763        NaN            NaN         NaN                 NaN          NaN
# 4764        NaN            NaN         NaN                 NaN          NaN
# 4765        NaN            NaN         NaN                 NaN          NaN
# 4766        NaN            NaN         NaN                 NaN          NaN
# 4767        NaN            NaN         NaN                 NaN          NaN
# 4768        NaN            NaN         NaN                 NaN          NaN
# 4769        NaN            NaN         NaN                 NaN          NaN
# 4770        NaN            NaN         NaN                 NaN          NaN
# 4771        NaN            NaN         NaN                 NaN          NaN
# 4772        NaN            NaN         NaN                 NaN          NaN
# 4773        NaN            NaN         NaN                 NaN          NaN
# 4774        NaN            NaN         NaN                 NaN          NaN
# 4775        NaN            NaN         NaN                 NaN          NaN
# 4776        NaN            NaN         NaN                 NaN          NaN
# 4777        NaN            NaN         NaN                 NaN          NaN
# 4778        NaN            NaN         NaN                 NaN          NaN
# 4779        NaN            NaN         NaN                 NaN          NaN
#
#             postingTime readingTime  \
# 337   February 14, 2016
# 1633                NaN
# 2366    August 25, 2016
# 2666                NaN
# 3781   November 2, 2017
# 4725                NaN         NaN
# 4727                NaN         NaN
# 4728                NaN         NaN
# 4729                NaN         NaN
# 4730                NaN         NaN
# 4731                NaN         NaN
# 4732                NaN         NaN
# 4733                NaN         NaN
# 4734                NaN         NaN
# 4735                NaN         NaN
# 4736                NaN         NaN
# 4737                NaN         NaN
# 4738                NaN         NaN
# 4739                NaN         NaN
# 4740                NaN         NaN
# 4741                NaN         NaN
# 4742                NaN         NaN
# 4743                NaN         NaN
# 4744                NaN         NaN
# 4745                NaN         NaN
# 4746                NaN         NaN
# 4747                NaN         NaN
# 4748                NaN         NaN
# 4749                NaN         NaN
# 4750                NaN         NaN
# 4751                NaN         NaN
# 4752                NaN         NaN
# 4753                NaN         NaN
# 4754                NaN         NaN
# 4755                NaN         NaN
# 4756                NaN         NaN
# 4757                NaN         NaN
# 4758                NaN         NaN
# 4759                NaN         NaN
# 4760                NaN         NaN
# 4761                NaN         NaN
# 4762                NaN         NaN
# 4763                NaN         NaN
# 4764                NaN         NaN
# 4765                NaN         NaN
# 4766                NaN         NaN
# 4767                NaN         NaN
# 4768                NaN         NaN
# 4769                NaN         NaN
# 4770                NaN         NaN
# 4771                NaN         NaN
# 4772                NaN         NaN
# 4773                NaN         NaN
# 4774                NaN         NaN
# 4775                NaN         NaN
# 4776                NaN         NaN
# 4777                NaN         NaN
# 4778                NaN         NaN
# 4779                NaN         NaN
#
#                                                                                                                              articleLink
# 337                                          https://dickeysingh.com/2016/02/14/growth-hacking-is-part-art-and-part-science-68e48329915/
# 1633                                       https://medium.com/@upal/how-to-use-machine-learning-to-debug-outages-10x-faster-e480b7e2a907
# 2366                                                                 https://blog.locus.sh/we-see-dimensions-that-you-wont-3a5f760dd198/
# 2666                                                                                                            https://data.world/blog/
# 3781                                                                          https://blog.locus.sh/followed-by-randomness-245d4f7d6f64/
# 4725                                             https://blog.ahmedkamal.me/why-should-you-care-about-big-data-data-science-cbf3ea5c7aef
# 4727         https://genomix.me/molecular-predictors-of-alzheimer-s-disease-a-collaboration-with-sage-bionetworks-my-insight-1c130524d39
# 4728                                 https://blog.transcendingdigital.space/the-future-will-be-built-on-open-data-heres-why-f76495507da9
# 4729                                                     https://dickeysingh.com/growth-hacking-is-part-art-and-part-science-68e48329915
# 4730                                                                 https://blog.tracchicago.com/how-much-data-is-too-much-a1bbed7f7688
# 4731                                                           https://blog.transcendingdigital.space/importing-data-into-r-3eef638dcd6a
# 4732                                                                     https://blog.patricknieto.com/hi-there-i-m-patrick-dd030f9f9e9b
# 4733                                                    https://blog.tomorrowjobs.co/interview-etre-datascientist-c-est-quoi-f289623748a
# 4734                         https://blog.tomorrowjobs.co/infographie-tout-ce-que-vous-devez-savoir-sur-les-data-scientists-319bf9d6b1b3
# 4735                                                                          https://blog.patricknieto.com/week-one-re-cap-e1a514713d96
# 4736                                                        https://thenairaguy.com/predicting-epl-matches-with-mathematics-481cbfbed3a2
# 4737                                                    https://blog.patricknieto.com/am-i-washed-up-movie-data-exploration-968437038cfe
# 4738                                                                  https://stevetrask.com/tytmd-great-data-visualization-9ee26227ce68
# 4739                                  https://ensemble.redoakstrategic.com/uber-lyft-using-campaign-data-science-to-succeed-e4f39c395f01
# 4740                                                       https://newsletter.jupyter.org/jupyter-newsletter-4-june-15-2016-8be858ef29dc
# 4741                                                     https://johnwilson.co/5-personality-traits-every-analyst-must-have-2047b454e6ce
# 4742                                                                https://blog.satalia.com/what-is-prescriptive-analytics-4178366f2080
# 4743                            https://signalforprogress.com/how-lord-abbett-used-infors-data-science-to-gain-a-sales-edge-945e043757a7
# 4744                                               https://zaga.com.ng/naive-bayes-supervised-classifier-put-in-perspective-57f003ebb29e
# 4745                                           https://blog.datarecipe.com/creating-the-data-recipe-development-environment-11ff5cc08594
# 4746                                               https://nlpwave.com/towards-becoming-a-full-stack-computational-linguist-34a11d75e13f
# 4747                                                         https://bullshit.mx/lo-que-quiso-decir-el-presidente-pe%C3%B1a-9b24fc8d6c89
# 4748                                                                        https://blog.mytomorrows.com/joy-of-coding-2016-2695fcd0b77b
# 4749                                       https://ensemble.redoakstrategic.com/tracking-2016-using-google-consumer-surveys-d443bc8fe392
# 4750                                                                               https://johnwilson.co/yogi-and-your-data-5c00fe3c6cdb
# 4751                                                                  https://blog.locus.sh/we-see-dimensions-that-you-wont-3a5f760dd198
# 4752                              https://ensemble.redoakstrategic.com/could-google-and-xbox-solve-all-of-pollings-problems-3c87f4d6e40a
# 4753                                                                                  https://realworldcoding.io/why-i-code-fc86bb0db723
# 4754                                                                              https://meta.data.world/notebook-previews-c239d804cbc2
# 4755                                                                    https://meta.data.world/organizations-on-data-world-dc52edbba738
# 4756                                                                    https://datumlab.io/data-science-cloud-optimization-96f6b1bc8482
# 4757                                 https://meta.data.world/oooh-i-can-help-with-that-what-contribution-means-in-data-work-ebd929acede0
# 4758                                                                                        https://blog.keen.io/lesson-one-6495d7b4ddec
# 4759                                                        https://blog.trustar.co/increase-your-chances-of-catching-a-rat-199bcb439f93
# 4760                                                                            https://johnwilson.co/data-of-unusual-sizes-7171b19d0dab
# 4761                                                             https://swedgin.com/predicting-ctrs-on-criteos-display-ads-ad669a601125
# 4762                                                               https://blog.vbweb.in/data-analysis-for-bollywood-movies-5312c30ee454
# 4763                                                                    https://blog.vbweb.in/the-silent-pm-of-india-really-c5bc62ec07b3
# 4764                                                             https://swedgin.com/predicting-ctrs-on-criteos-display-ads-270b4a4137b2
# 4765                                                     https://thenairaguy.com/machine-learning-predicting-customer-churn-63846fc127f4
# 4766                                      https://misdirectedbehavior.com/when-data-isnt-enough-how-to-build-for-perception-3859c0f1bda2
# 4767       https://signalforprogress.com/from-scrubbing-up-to-geeking-out-a-q-a-with-infor-nurse-executive-elizabeth-meyers-9e4e0e01ccb8
# 4768                                             https://points.datasociety.net/safety-checklists-for-sociotechnical-design-2cb9192e9e3b
# 4769                                                                           https://blog.locus.sh/followed-by-randomness-245d4f7d6f64
# 4770                             https://blog.data.world/datasets-digest-witchcraft-accusations-chicago-crime-cats-and-dogs-7285e5844fb3
# 4771                                                                 https://medium.com/@neocortex/spark-summit-europe-2016-7450ea85a451
# 4772             https://blog.data.world/datasets-digest-marijuana-legalization-veteran-demographics-radio-play-predictions-7e133f792c2d
# 4773                                                              https://blog.anilshanbhag.in/analyzing-the-2016-elections-4944f6e6515c
# 4774                  https://blog.data.world/6-things-we-learned-from-the-most-comprehensive-product-hunt-api-dataset-ever-8bee1a5ad50a
# 4775                                                                 https://bradystats.com/finding-mlb-anomalies-with-cade-c90010464f0a
# 4776                            https://swedgin.com/exploring-unsupervised-learning-and-dimensionality-reduction-algorithms-1e225fafa14e
# 4777  https://blog.data.world/datasets-digest-sea-level-change-trends-hackernews-most-popular-stories-u-s-worker-fatalities-8d8d93f4a69d
# 4778                                                                  https://prsharma.me/frequentists-vs-bayesians-into-ml-1709cc77598f
# 4779                                                     https://blog.gabrielfv.com/scraping-f%C3%A1cil-com-python-e-scrapy-d1e4c5c0c65e

# %% [markdown]
# ## Try to scrape links missing tags --> failed

# %% [raw]
# import scrapy
# from scrapy.crawler import CrawlerProcess
# from scrapy.utils.log import configure_logging
# import logging
#
# import os
# os.chdir('/Users/nancy/PycharmProjects/medium-ds-articles/data/raw/')
#
# class Article(scrapy.Item):
#     nameOfAuthor = scrapy.Field()
#     linkOfAuthorProfile = scrapy.Field()
#     NumOfComments = scrapy.Field()
#     article = scrapy.Field()
#     postingTime = scrapy.Field()
#     NumOfClaps = scrapy.Field()
#     articleURL = scrapy.Field()
#     articleTags = scrapy.Field()
#     readingTime = scrapy.Field()
#
# logger = logging.getLogger('testlogger')
#
#
# class IntroSpider(scrapy.Spider):
#     name = "intro_spider"
#
#
#     configure_logging(install_root_handler=False)
#     logging.basicConfig(
#         filename='medium_full_2018_missing_tags_log.txt',
#         format='%(levelname)s: %(message)s',
#         level=logging.INFO
#     )
#
#     custom_settings = {
#         'FEED_FORMAT': 'csv',
#         'FEED_URI': 'medium_2018_missing_tags.csv',
#         'AUTOTHROTTLE_ENABLED' : True,
#         'AUTOTHROTTLE_START_DELAY' : 1,
#         'AUTOTHROTTLE_MAX_DELAY' : 3
#     }
#
#
#     def start_requests(self):
#         for i in urls_missing_tags['articleLink']:
#             yield scrapy.Request(url=i, callback=self.parse)
#
#
#     def parse(self, response):
#         item = Article()
#
#         for story in response.css('div.postArticle'):
#             if story.css('div.postArticle-readMore a::attr(href)').extract_first() is not None:
#                 url = story.css('div.postArticle-readMore a::attr(href)').extract_first()
#                 yield scrapy.Request(url=url, callback=self.parse_tags, meta={'item': item})
#
#     def parse_tags(self, response):
#
#         item = response.meta['item']
#         item['articleURL'] = response.request.url
# #         item['article'] = response.css('div.postArticle-content section div.section-content div h1::text, \
# #                                         div.postArticle-content section div.section-content div h1 a::text, \
# #                                         div.postArticle-content section div.section-content div h1 strong::text,\
# #                                         div.postArticle-content section div.section-content div h1 em::text, \
# #                                         div.postArticle-content section div.section-content div h3::text, \
# #                                         div.postArticle-content section div.section-content div h4::text, \
# #                                         div.postArticle-content section div.section-content div p strong::text, \
# #                                         div.postArticle-content section div.section-content div p strong em::text, \
# #                                         div.postArticle-content section div.section-content div p::text').extract_first()
#
#
# #         item['article'] = response.xpath('//div/main/article/div/section/div[2]/div/h1//text() | //div/main/article/div/section/div[2]/div/h4//text() | //div/main/article/div/section/div[2]/div/h1/a//text() | //div/main/article/div/section/div[2]/div/h1/strong//text() | //div/main/article/div/section/div[2]/div/h1/em//text() | //div/main/article/div/section/div[2]/div/p//text()').extract_first()
#
#
#         try:
#             item['linkOfAuthorProfile'] = response.css('div.u-paddingBottom3 a').attrib['href']
#         except KeyError:
#             item['linkOfAuthorProfile'] = ' '
#
#         try:
#             item['readingTime'] = response.css('span.readingTime').attrib['title']
#         except KeyError:
#             item['readingTime'] = ' '
#
#
#         item['nameOfAuthor'] = response.css('div.u-paddingBottom3 a::text').extract_first()
#         item['postingTime'] = response.css('time::text').extract_first()
#         item['articleTags'] = response.css('div.u-paddingBottom10 ul.tags--postTags li a::text').getall()
#         item['NumOfComments'] = response.css(
#             'div.buttonSet.u-flex0 button.button.button--chromeless.u-baseColor--buttonNormal.u-marginRight12::text').extract_first()
#         item['NumOfClaps'] = response.xpath(
#             '//div/main/article/footer/div[1]/div[3]/div/div[1]/div/span/button//text()').extract_first()
#
#
#         yield item
#
#
# process = CrawlerProcess({
#     'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
# })
#
# process.crawl(IntroSpider)
# process.start()

# %% [markdown]
# ## Prepare tags data

# %%
tags = merged['articleTags'].str.split(',', expand=True)

tags = tags.fillna('')

# %%
tags.replace('Data Science', '', inplace=True)
tags.replace('Datascience', '', inplace=True)

# %%
tags.to_csv('2016_tags.csv', index=False)

# %% [markdown]
# ## Itemset mining

# %%
# %%R
#
# library(arules)
#
# tr <- read.transactions("2016_tags.csv", format = 'basket', sep=',')
# Out:
# R[write to console]: Error in file(con, "r") : cannot open the connection
# Calls: <Anonymous> ... withVisible -> read.transactions -> lapply -> readLines -> file
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In file(con, "r") :
# R[write to console]:
#
# R[write to console]:  cannot open file '2016_tags.csv': No such file or directory
# Error in file(con, "r") : cannot open the connection
# Calls: <Anonymous> ... withVisible -> read.transactions -> lapply -> readLines -> file

# %%
# %%R
#
# summary(tr)
# Out:
# transactions as itemMatrix in sparse format with
#  4780 rows (elements/itemsets/transactions) and
#  2363 columns (items) and a density of 0.001144386
#
# most frequent items:
#                Big Data        Machine Learning      Data Visualization
#                    1460                    1073                     476
#               Analytics Artificial Intelligence                 (Other)
#                     421                     337                    9159
#
# element (itemset/transaction) length distribution:
# sizes
#    0    1    2    3    4    5
#  102  712 1503  645 1817    1
#
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   2.000   3.000   2.704   4.000   5.000
#
# includes extended item information - examples:
#   labels
# 1      0
# 2      1
# 3      2

# %%
# %%R
#
# itms <- itemFrequency(tr, type = "relative")
# data.frame(sort(itms, decreasing = TRUE))
# Out:
#                           sort.itms..decreasing...TRUE.
# Big Data                                   0.3054393305
# Machine Learning                           0.2244769874
# Data Visualization                         0.0995815900
# Analytics                                  0.0880753138
# Artificial Intelligence                    0.0705020921
# Data                                       0.0483263598
# Python                                     0.0445606695
# Startup                                    0.0435146444
# Statistics                                 0.0357740586
# Tech                                       0.0297071130
# Programming                                0.0288702929
# Technology                                 0.0240585774
# Data Analysis                              0.0232217573
# Open Data                                  0.0207112971
# Marketing                                  0.0198744770
# Deep Learning                              0.0192468619
# Politics                                   0.0186192469
# Education                                  0.0184100418
# Science                                    0.0177824268
# Design                                     0.0148535565
# Business                                   0.0131799163
# R                                          0.0127615063
# Software Development                       0.0125523013
# Big Data Analytics                         0.0123430962
# Business Intelligence                      0.0123430962
# 2016 Election                              0.0119246862
# Predictive Analytics                       0.0117154812
# Rstats                                     0.0110878661
# Research                                   0.0092050209
# Algorithms                                 0.0089958159
# Hadoop                                     0.0089958159
# Healthcare                                 0.0089958159
# Data Engineering                           0.0085774059
# Data Mining                                0.0085774059
# Open Source                                0.0081589958
# Social Media                               0.0081589958
# Recruiting                                 0.0079497908
# IoT                                        0.0077405858
# R Programming                              0.0077405858
# Data Analytics                             0.0075313808
# Entrepreneurship                           0.0075313808
# Health                                     0.0071129707
# Product Management                         0.0071129707
# Government                                 0.0069037657
# Innovation                                 0.0066945607
# Mathematics                                0.0066945607
# AI                                         0.0064853556
# Economics                                  0.0062761506
# Apache Spark                               0.0060669456
# Hiring                                     0.0060669456
# Twitter                                    0.0060669456
# Women In Tech                              0.0058577406
# Cloud Computing                            0.0056485356
# Computer Science                           0.0052301255
# Sports                                     0.0052301255
# Pandas                                     0.0050209205
# Web Development                            0.0050209205
# Donald Trump                               0.0048117155
# Insight Data Science                       0.0048117155
# Jobs                                       0.0048117155
# Jupyter                                    0.0048117155
# NLP                                        0.0048117155
# Climate Change                             0.0046025105
# Digital Marketing                          0.0046025105
# Finance                                    0.0046025105
# Journalism                                 0.0046025105
# R Language                                 0.0046025105
# Startups                                   0.0046025105
# UX                                         0.0046025105
# Careers                                    0.0043933054
# Coding                                     0.0043933054
# Data Management                            0.0043933054
# Data Scientist                             0.0043933054
# Internet of Things                         0.0043933054
# Music                                      0.0043933054
# Tutorial                                   0.0043933054
# Data Journalism                            0.0041841004
# Spark                                      0.0041841004
# Ecommerce                                  0.0039748954
# GIS                                        0.0039748954
# Learning                                   0.0039748954
# Management                                 0.0039748954
# Maps                                       0.0039748954
# TensorFlow                                 0.0039748954
# Web Scraping                               0.0039748954
# Environment                                0.0037656904
# Facebook                                   0.0037656904
# JavaScript                                 0.0037656904
# Learning To Code                           0.0037656904
# Neural Networks                            0.0037656904
# Privacy                                    0.0037656904
# Psychology                                 0.0037656904
# Towards Data Science                       0.0037656904
# Big Data Analysis                          0.0035564854
# Fintech                                    0.0035564854
# API                                        0.0033472803
# Database                                   0.0033472803
# Engineering                                0.0033472803
# Recommendation System                      0.0033472803
# Clustering                                 0.0031380753
# Information Technology                     0.0031380753
# Travel                                     0.0031380753
# Advertising                                0.0029288703
# DevOps                                     0.0029288703
# Google                                     0.0029288703
# Interview                                  0.0029288703
# Movies                                     0.0029288703
# Rstudio                                    0.0029288703
# Security                                   0.0029288703
# Sql                                        0.0029288703
# Writing                                    0.0029288703
# Analysis                                   0.0027196653
# Content Marketing                          0.0027196653
# Decision Making                            0.0027196653
# Hackathons                                 0.0027196653
# Higher Education                           0.0027196653
# Mobile                                     0.0027196653
# Natural Language                           0.0027196653
# NYU                                        0.0027196653
# Productivity                               0.0027196653
# Visualization                              0.0027196653
# AWS                                        0.0025104603
# Business Analytics                         0.0025104603
# Business Strategy                          0.0025104603
# Customer Experience                        0.0025104603
# Docker                                     0.0025104603
# Ethics                                     0.0025104603
# Excel                                      0.0025104603
# Growth                                     0.0025104603
# Hillary Clinton                            0.0025104603
# Life Lessons                               0.0025104603
# NoSQL                                      0.0025104603
# Pokemon                                    0.0025104603
# Retail                                     0.0025104603
# Smart Cities                               0.0025104603
# Venture Capital                            0.0025104603
# Weather                                    0.0025104603
# Books                                      0.0023012552
# Career Advice                              0.0023012552
# Coursera                                   0.0023012552
# Cybersecurity                              0.0023012552
# IBM                                        0.0023012552
# Outsourcing                                0.0023012552
# Product Design                             0.0023012552
# Publishing                                 0.0023012552
# SaaS                                       0.0023012552
# Social Science                             0.0023012552
# Testing                                    0.0023012552
# Transportation                             0.0023012552
# Virtual Reality                            0.0023012552
# Chatbots                                   0.0020920502
# Ciencia De Dados                           0.0020920502
# Dashboard                                  0.0020920502
# Gaming                                     0.0020920502
# Health Technology                          0.0020920502
# Insight Health Data                        0.0020920502
# Insights                                   0.0020920502
# Microsoft                                  0.0020920502
# Mongodb                                    0.0020920502
# Project Management                         0.0020920502
# Sales                                      0.0020920502
# Serenata De Amor                           0.0020920502
# Apache Hadoop                              0.0018828452
# Automation                                 0.0018828452
# Bots                                       0.0018828452
# Brasil                                     0.0018828452
# Conference                                 0.0018828452
# Criminal Justice                           0.0018828452
# Digital Transformation                     0.0018828452
# Distributed Systems                        0.0018828452
# Diversity                                  0.0018828452
# Energy                                     0.0018828452
# Growth Hacking                             0.0018828452
# Insight Data Engineering                   0.0018828452
# Kaggle                                     0.0018828452
# Market Research                            0.0018828452
# Media                                      0.0018828452
# Metrics                                    0.0018828452
# Optimization                               0.0018828452
# Product Development                        0.0018828452
# Self Driving Cars                          0.0018828452
# Sentiment Analysis                         0.0018828452
# Strategy                                   0.0018828452
# Algorithm                                  0.0016736402
# Banking                                    0.0016736402
# Bayesian Statistics                        0.0016736402
# Bigdata                                    0.0016736402
# Blockchain                                 0.0016736402
# Computer Vision                            0.0016736402
# Costa Rica                                 0.0016736402
# Dataviz                                    0.0016736402
# Digital                                    0.0016736402
# Employee Engagement                        0.0016736402
# Github                                     0.0016736402
# Google Analytics                           0.0016736402
# Humor                                      0.0016736402
# Insurance                                  0.0016736402
# Leadership                                 0.0016736402
# Math                                       0.0016736402
# Music Theory                               0.0016736402
# News                                       0.0016736402
# Nonprofit                                  0.0016736402
# Podcast                                    0.0016736402
# Real Estate                                0.0016736402
# Running                                    0.0016736402
# San Francisco                              0.0016736402
# Software Engineering                       0.0016736402
# User Experience                            0.0016736402
# Wearables                                  0.0016736402
# Webinar                                    0.0016736402
# Ab Testing                                 0.0014644351
# Bigquery                                   0.0014644351
# Bpo                                        0.0014644351
# Brexit                                     0.0014644351
# Charts                                     0.0014644351
# Code                                       0.0014644351
# Collaboration                              0.0014644351
# Communication                              0.0014644351
# Consulting                                 0.0014644351
# Content Strategy                           0.0014644351
# Corporate Culture                          0.0014644351
# Creativity                                 0.0014644351
# CRM                                        0.0014644351
# Culture                                    0.0014644351
# D3                                         0.0014644351
# Data Driven                                0.0014644351
# Design Thinking                            0.0014644351
# Etl                                        0.0014644351
# Food                                       0.0014644351
# Future                                     0.0014644351
# Future Of Work                             0.0014644351
# Gender Equality                            0.0014644351
# Genomics                                   0.0014644351
# Harvard                                    0.0014644351
# Infographics                               0.0014644351
# Language                                   0.0014644351
# Linear Regression                          0.0014644351
# Naturallanguageprocessing                  0.0014644351
# Newsletter                                 0.0014644351
# Personalization                            0.0014644351
# Polling                                    0.0014644351
# Python Data Analysis                       0.0014644351
# Racism                                     0.0014644351
# Redshift                                   0.0014644351
# Social Network Analysis                    0.0014644351
# Text Mining                                0.0014644351
# Udacity                                    0.0014644351
# Video                                      0.0014644351
# Academia                                   0.0012552301
# Agriculture                                0.0012552301
# Airbnb                                     0.0012552301
# Amazon                                     0.0012552301
# Android                                    0.0012552301
# Announcements                              0.0012552301
# Apps                                       0.0012552301
# Augmented Reality                          0.0012552301
# Autonomous Cars                            0.0012552301
# Azure                                      0.0012552301
# Bioinformatics                             0.0012552301
# Blogging                                   0.0012552301
# Causality                                  0.0012552301
# Cities                                     0.0012552301
# Classification                             0.0012552301
# Competition                                0.0012552301
# Correlation                                0.0012552301
# Data Governance                            0.0012552301
# Data Integration                           0.0012552301
# Experimentation                            0.0012552301
# Fitness                                    0.0012552301
# Google Cloud Platform                      0.0012552301
# India                                      0.0012552301
# Job Hunting                                0.0012552301
# Json                                       0.0012552301
# Jupyter Notebook                           0.0012552301
# Lean Startup                               0.0012552301
# Linguistics                                0.0012552301
# LinkedIn                                   0.0012552301
# Medicine                                   0.0012552301
# NBA                                        0.0012552301
# Neo4j                                      0.0012552301
# Neuroscience                               0.0012552301
# New York City                              0.0012552301
# Philanthropy                               0.0012552301
# Philosophy                                 0.0012552301
# Poetry                                     0.0012552301
# Post Academia                              0.0012552301
# Programmatic                               0.0012552301
# Regression                                 0.0012552301
# Salary                                     0.0012552301
# Scala                                      0.0012552301
# Scikit Learn                               0.0012552301
# Search                                     0.0012552301
# Self Improvement                           0.0012552301
# Social Change                              0.0012552301
# Social Network                             0.0012552301
# Tableau                                    0.0012552301
# Training                                   0.0012552301
# Africa                                     0.0010460251
# Analise De Dados                           0.0010460251
# Austin                                     0.0010460251
# Benchmark                                  0.0010460251
# Big Data And Analytics                     0.0010460251
# Brazil                                     0.0010460251
# Career                                     0.0010460251
# Civictech                                  0.0010460251
# Cloud Catalog                              0.0010460251
# Cognitive Computing                        0.0010460251
# Commentary                                 0.0010460251
# Company Culture                            0.0010460251
# Crime                                      0.0010460251
# Crowdsourcing                              0.0010460251
# Data Visualisation                         0.0010460251
# Data Warehouse                             0.0010460251
# Dataops                                    0.0010460251
# Disruptive Innovation                      0.0010460251
# Econometrics                               0.0010460251
# Economy                                    0.0010460251
# Elasticsearch                              0.0010460251
# Employment                                 0.0010460251
# Esports                                    0.0010460251
# Feminism                                   0.0010460251
# Flowchart                                  0.0010460251
# Football                                   0.0010460251
# Functional Programming                     0.0010460251
# Graph Database                             0.0010460251
# Hacking                                    0.0010460251
# Hcde 210                                   0.0010460251
# HR                                         0.0010460251
# Human In The Loop                          0.0010460251
# Human Resources                            0.0010460251
# Indonesia                                  0.0010460251
# Inteligencia Competitiva                   0.0010460251
# Java                                       0.0010460251
# Law                                        0.0010460251
# Life                                       0.0010460251
# Life Hacking                               0.0010460251
# Logistics                                  0.0010460251
# Mobile App Development                     0.0010460251
# NASA                                       0.0010460251
# Nodejs                                     0.0010460251
# Olympics                                   0.0010460251
# Organizational Culture                     0.0010460251
# Panama Papers                              0.0010460251
# Predictive Modeling                        0.0010460251
# Probability                                0.0010460251
# Product Data                               0.0010460251
# Programming Languages                      0.0010460251
# Public Health                              0.0010460251
# Public Policy                              0.0010460251
# Reproducibility                            0.0010460251
# Robotics                                   0.0010460251
# Ruby                                       0.0010460251
# Sharing Economy                            0.0010460251
# Slack                                      0.0010460251
# Soccer                                     0.0010460251
# Social Good                                0.0010460251
# Sociology                                  0.0010460251
# Teaching                                   0.0010460251
# Technology News                            0.0010460251
# Tecnologia                                 0.0010460251
# Thinking                                   0.0010460251
# Uber                                       0.0010460251
# Urban Planning                             0.0010460251
# User Research                              0.0010460251
# Yelp                                       0.0010460251
# Adtech                                     0.0008368201
# Agile                                      0.0008368201
# Anaconda                                   0.0008368201
# Apple                                      0.0008368201
# Astronomy                                  0.0008368201
# Biology                                    0.0008368201
# Biostatistics                              0.0008368201
# Business Development                       0.0008368201
# Business Models                            0.0008368201
# Cancer                                     0.0008368201
# Charity                                    0.0008368201
# Chicago                                    0.0008368201
# Coding Bootcamps                           0.0008368201
# College                                    0.0008368201
# College Admissions                         0.0008368201
# Community                                  0.0008368201
# Complexity                                 0.0008368201
# Compression                                0.0008368201
# Conferences                                0.0008368201
# Customer                                   0.0008368201
# Cycling                                    0.0008368201
# Data Driven Decisions                      0.0008368201
# Data Driven Journalism                     0.0008368201
# Data Preparation                           0.0008368201
# Data Quality                               0.0008368201
# Data Wrangling                             0.0008368201
# Decision Tree                              0.0008368201
# Drones                                     0.0008368201
# Edtech                                     0.0008368201
# Education Technology                       0.0008368201
# Emotions                                   0.0008368201
# European Union                             0.0008368201
# Geospatial                                 0.0008368201
# Hackathon                                  0.0008368201
# History                                    0.0008368201
# How To                                     0.0008368201
# Hrtech                                     0.0008368201
# Ibm Watson                                 0.0008368201
# Ideas                                      0.0008368201
# Image Processing                           0.0008368201
# Information                                0.0008368201
# Insight Ai                                 0.0008368201
# Instagram                                  0.0008368201
# Internships                                0.0008368201
# Introduction                               0.0008368201
# Ipython                                    0.0008368201
# Linked Data                                0.0008368201
# London                                     0.0008368201
# Marathon                                   0.0008368201
# Matlab                                     0.0008368201
# Meetup                                     0.0008368201
# Mental Health                              0.0008368201
# Mooc                                       0.0008368201
# Netflix                                    0.0008368201
# Network Science                            0.0008368201
# Networking                                 0.0008368201
# NFL                                        0.0008368201
# Oceans                                     0.0008368201
# Online Courses                             0.0008368201
# Open Science                               0.0008368201
# Parenting                                  0.0008368201
# Personal Development                       0.0008368201
# Physics                                    0.0008368201
# Police                                     0.0008368201
# Policy                                     0.0008368201
# Product                                    0.0008368201
# Projetos                                   0.0008368201
# Python Web Developer                       0.0008368201
# R Studio                                   0.0008368201
# Recommender Systems                        0.0008368201
# Reddit                                     0.0008368201
# Research Reports                           0.0008368201
# Russian                                    0.0008368201
# Salesforce                                 0.0008368201
# Satellite Technology                       0.0008368201
# Search Engines                             0.0008368201
# Segmentation                               0.0008368201
# Small Business                             0.0008368201
# Social Impact                              0.0008368201
# Social Innovation                          0.0008368201
# Social Selling                             0.0008368201
# Society                                    0.0008368201
# Software                                   0.0008368201
# Space                                      0.0008368201
# Stock Market                               0.0008368201
# Storytelling                               0.0008368201
# Tools                                      0.0008368201
# Trust                                      0.0008368201
# United Nations                             0.0008368201
# Unsupervised Learning                      0.0008368201
# Volunteering                               0.0008368201
# Washington DC                              0.0008368201
# Wikipedia                                  0.0008368201
# Wmd                                        0.0008368201
# 2016                                       0.0006276151
# Accounting                                 0.0006276151
# Aclima                                     0.0006276151
# Air Quality                                0.0006276151
# Apache Kafka                               0.0006276151
# Art                                        0.0006276151
# Audio                                      0.0006276151
# Automotive                                 0.0006276151
# AWS Lambda                                 0.0006276151
# Baseball                                   0.0006276151
# Bash                                       0.0006276151
# Big Data Courses                           0.0006276151
# Big Market Research                        0.0006276151
# Black Friday                               0.0006276151
# Book Review                                0.0006276151
# Business Analysis                          0.0006276151
# Career Change                              0.0006276151
# Case Study                                 0.0006276151
# Causation                                  0.0006276151
# Change Management                          0.0006276151
# Christmas                                  0.0006276151
# Civic Hacking                              0.0006276151
# Cloud                                      0.0006276151
# Cognitive Bias                             0.0006276151
# Computational Linguistics                  0.0006276151
# Computers                                  0.0006276151
# Congress                                   0.0006276151
# Construction                               0.0006276151
# Cooking                                    0.0006276151
# Corruption                                 0.0006276151
# Criminal Justice Reform                    0.0006276151
# Csr                                        0.0006276151
# Customer Service                           0.0006276151
# Data Modeling                              0.0006276151
# Data Storytelling                          0.0006276151
# Datacamp                                   0.0006276151
# Dating                                     0.0006276151
# Design Research                            0.0006276151
# Disruption                                 0.0006276151
# Edx                                        0.0006276151
# Emojis                                     0.0006276151
# Enterprise Technology                      0.0006276151
# Events                                     0.0006276151
# Fantasy Football                           0.0006276151
# Fashion                                    0.0006276151
# Film                                       0.0006276151
# Forecasting                                0.0006276151
# Foreign Policy                             0.0006276151
# Foursquare                                 0.0006276151
# Gartner                                    0.0006276151
# Geek                                       0.0006276151
# Global Warming                             0.0006276151
# Gradient Descent                           0.0006276151
# Graphs                                     0.0006276151
# Guns                                       0.0006276151
# Health Data Science                        0.0006276151
# Home                                       0.0006276151
# Homepage                                   0.0006276151
# Humanity                                   0.0006276151
# Infolettre                                 0.0006276151
# Information Architecture                   0.0006276151
# Information Security                       0.0006276151
# Interviews                                 0.0006276151
# Investing                                  0.0006276151
# John Hopkins                               0.0006276151
# Journal                                    0.0006276151
# Julialang                                  0.0006276151
# Kickstarter                                0.0006276151
# Knowledge                                  0.0006276151
# Knowledge Management                       0.0006276151
# Kpi                                        0.0006276151
# Labs                                       0.0006276151
# Linux                                      0.0006276151
# Location Intelligence                      0.0006276151
# Mapping                                    0.0006276151
# Marketing Automation                       0.0006276151
# Marketing Technology                       0.0006276151
# Markov Chains                              0.0006276151
# Mexico                                     0.0006276151
# Mobile Marketing                           0.0006276151
# Modeling                                   0.0006276151
# Models                                     0.0006276151
# Monitoramento                              0.0006276151
# MySQL                                      0.0006276151
# Numpy                                      0.0006276151
# NYC                                        0.0006276151
# Open Government                            0.0006276151
# Opendata                                   0.0006276151
# Operations                                 0.0006276151
# Operations Research                        0.0006276151
# Oracle                                     0.0006276151
# Pebble                                     0.0006276151
# People                                     0.0006276151
# Pokemon Go                                 0.0006276151
# Policy Analytics                           0.0006276151
# Power Bi                                   0.0006276151
# PPC Marketing                              0.0006276151
# Predictions                                0.0006276151
# Public Transit                             0.0006276151
# Quantified Self                            0.0006276151
# Random Forest                              0.0006276151
# Refugees                                   0.0006276151
# Resources                                  0.0006276151
# Samza                                      0.0006276151
# Satire                                     0.0006276151
# Science Fiction                            0.0006276151
# Scikitlearn                                0.0006276151
# Signal Processing                          0.0006276151
# Social Media Marketing                     0.0006276151
# Socintrof2016                              0.0006276151
# Socintrof2016 Unit 1                       0.0006276151
# Spanish                                    0.0006276151
# Speech                                     0.0006276151
# Sports Analytics                           0.0006276151
# Spotify                                    0.0006276151
# Spreadsheets                               0.0006276151
# Stream Processing                          0.0006276151
# Syria                                      0.0006276151
# Technews                                   0.0006276151
# Tennis                                     0.0006276151
# Text Analytics                             0.0006276151
# Thanksgiving                               0.0006276151
# Topic Modeling                             0.0006276151
# Universe                                   0.0006276151
# Vahula                                     0.0006276151
# Variable Selection                         0.0006276151
# Web Analytics                              0.0006276151
# Weight Loss                                0.0006276151
# Women                                      0.0006276151
# Women Who Reign                            0.0006276151
# 2016 Predictions                           0.0004184100
# A B Testing                                0.0004184100
# Academic                                   0.0004184100
# Accenture                                  0.0004184100
# Airbnb Pricing                             0.0004184100
# Andela                                     0.0004184100
# Android App Development                    0.0004184100
# Animals                                    0.0004184100
# Anova                                      0.0004184100
# Anthropology                               0.0004184100
# Apache Zeppelin                            0.0004184100
# App Store                                  0.0004184100
# Apparel                                    0.0004184100
# Apple Watch                                0.0004184100
# Application Software                       0.0004184100
# Arabic                                     0.0004184100
# Architecture                               0.0004184100
# Artifical Intelligence                     0.0004184100
# Audience Targeting                         0.0004184100
# Autism                                     0.0004184100
# Autodidacticism                            0.0004184100
# Baby Names                                 0.0004184100
# Balkanization                              0.0004184100
# Beginner                                   0.0004184100
# Behavior Change                            0.0004184100
# Behavioral Analytics                       0.0004184100
# Behavioural Economics                      0.0004184100
# Berlin                                     0.0004184100
# Bikes                                      0.0004184100
# Bikesharemachinelearning                   0.0004184100
# Biomass                                    0.0004184100
# Biometrics                                 0.0004184100
# Birthday                                   0.0004184100
# BlackLivesMatter                           0.0004184100
# Boston                                     0.0004184100
# Bpm                                        0.0004184100
# Buildings                                  0.0004184100
# Business Analyst                           0.0004184100
# By Topic                                   0.0004184100
# Caltrain                                   0.0004184100
# Câmara Dos Deputados                       0.0004184100
# Capitalism                                 0.0004184100
# Career Centre                              0.0004184100
# Career Development                         0.0004184100
# Cbm                                        0.0004184100
# Cdc                                        0.0004184100
# CEO                                        0.0004184100
# Certification                              0.0004184100
# Charts And Graphs                          0.0004184100
# Cheatsheet                                 0.0004184100
# Chief Data Officer                         0.0004184100
# Childrens Books                            0.0004184100
# China                                      0.0004184100
# Civil Rights                               0.0004184100
# Clemson                                    0.0004184100
# Climate                                    0.0004184100
# Clojure                                    0.0004184100
# Clothes                                    0.0004184100
# Codingbootcamp                             0.0004184100
# Coffee                                     0.0004184100
# Collective Intelligence                    0.0004184100
# College Football                           0.0004184100
# Columnists                                 0.0004184100
# Comedy                                     0.0004184100
# Community Update                           0.0004184100
# Competitive Intelligence                   0.0004184100
# Computational Biology                      0.0004184100
# Computer Programming                       0.0004184100
# Concept                                    0.0004184100
# Connectivity                               0.0004184100
# Consumer                                   0.0004184100
# Consumer Behavior                          0.0004184100
# Continuous Integration                     0.0004184100
# Conversations                              0.0004184100
# Conversion Optimization                    0.0004184100
# Counterparty                               0.0004184100
# Craft Beer                                 0.0004184100
# Credit Cards                               0.0004184100
# Criminology                                0.0004184100
# Customer Analytics                         0.0004184100
# Customer Journey                           0.0004184100
# Customer Success                           0.0004184100
# Data Analyst                               0.0004184100
# Data And Its Discontents                   0.0004184100
# Data Cleaning                              0.0004184100
# Data Lake                                  0.0004184100
# Data Literacy                              0.0004184100
# Data Makeover                              0.0004184100
# Data Pipeline                              0.0004184100
# Data Privacy                               0.0004184100
# Data Processing                            0.0004184100
# Data Science Engineering                   0.0004184100
# Data Security                              0.0004184100
# Data Storage                               0.0004184100
# Datamining                                 0.0004184100
# Demographics                               0.0004184100
# Deployment                                 0.0004184100
# Deutsch                                    0.0004184100
# Diabetes                                   0.0004184100
# Digital Disruption                         0.0004184100
# Digital Humanities                         0.0004184100
# Discovery                                  0.0004184100
# Diversity And Inclusion                    0.0004184100
# Do It Yourself                             0.0004184100
# Doctor Of Philosophy                       0.0004184100
# Drug Discovery                             0.0004184100
# Earnings                                   0.0004184100
# Earth Science                              0.0004184100
# Ecosystem                                  0.0004184100
# Electronics                                0.0004184100
# Email                                      0.0004184100
# Emprender                                  0.0004184100
# Encryption                                 0.0004184100
# Energy Efficiency                          0.0004184100
# Enterprise                                 0.0004184100
# Estadísticas Salud                         0.0004184100
# Ethnography                                0.0004184100
# Europe                                     0.0004184100
# Eventbrite                                 0.0004184100
# Exam                                       0.0004184100
# Executives                                 0.0004184100
# Expedia                                    0.0004184100
# Experimenting                              0.0004184100
# Exploratory                                0.0004184100
# Fabric                                     0.0004184100
# Fantasy Sports                             0.0004184100
# Features                                   0.0004184100
# Financial Technology                       0.0004184100
# First Post                                 0.0004184100
# Fitbit                                     0.0004184100
# France                                     0.0004184100
# Fraud                                      0.0004184100
# Freecodecamp                               0.0004184100
# Friendship                                 0.0004184100
# Funny                                      0.0004184100
# Game of Thrones                            0.0004184100
# Gender                                     0.0004184100
# General Assembly                           0.0004184100
# Geolocation                                0.0004184100
# Germar Reed                                0.0004184100
# Getting Started                            0.0004184100
# Git                                        0.0004184100
# Google Trends                              0.0004184100
# Graduate School                            0.0004184100
# Graphic Design                             0.0004184100
# Guest Post                                 0.0004184100
# Gun Violence                               0.0004184100
# Hacktivism                                 0.0004184100
# Harvard Business Review                    0.0004184100
# Hccfall2016                                0.0004184100
# Health Data                                0.0004184100
# Healthcare Technology                      0.0004184100
# Healthtech                                 0.0004184100
# Hello World                                0.0004184100
# Housing                                    0.0004184100
# Hranalytics                                0.0004184100
# Human Behavior                             0.0004184100
# Human Centered Design                      0.0004184100
# Human Rights                               0.0004184100
# Humanitarian                               0.0004184100
# Iiot                                       0.0004184100
# Industry 4 0                               0.0004184100
# Influencer Marketing                       0.0004184100
# Information Theory                         0.0004184100
# Infosec                                    0.0004184100
# Infotimes Blog                             0.0004184100
# Infrastructure                             0.0004184100
# Inspiration                                0.0004184100
# Intelligence                               0.0004184100
# Interaction Design                         0.0004184100
# Internal Audit                             0.0004184100
# Internet                                   0.0004184100
# Internship                                 0.0004184100
# Intuition                                  0.0004184100
# Investment                                 0.0004184100
# Japan                                      0.0004184100
# Job Interview                              0.0004184100
# K Means                                    0.0004184100
# Kafka                                      0.0004184100
# Kids And Tech                              0.0004184100
# Labeling Annotating                        0.0004184100
# Lda                                        0.0004184100
# Lead Generation                            0.0004184100
# Lessons Learned                            0.0004184100
# LGBTQ                                      0.0004184100
# Life Sciences                              0.0004184100
# Lifestyle                                  0.0004184100
# Linear Algebra                             0.0004184100
# Literature                                 0.0004184100
# Local Government                           0.0004184100
# Los Angeles                                0.0004184100
# Love                                       0.0004184100
# Machinelearninglabs                        0.0004184100
# Magento                                    0.0004184100
# Maintenance                                0.0004184100
# Manufacturing                              0.0004184100
# Mapreduce                                  0.0004184100
# Market Research Reports                    0.0004184100
# Marketing Analytics                        0.0004184100
# Marketing Digital                          0.0004184100
# Martech                                    0.0004184100
# Metadata                                   0.0004184100
# Microbiology                               0.0004184100
# Microservices                              0.0004184100
# Microsoft Azure                            0.0004184100
# Microsoft R Server                         0.0004184100
# Migration                                  0.0004184100
# Minneapolis                                0.0004184100
# Mixpanel                                   0.0004184100
# Mobile Health                              0.0004184100
# Monitoramento De Dados                     0.0004184100
# Mozilla                                    0.0004184100
# Networks                                   0.0004184100
# New York                                   0.0004184100
# Noaa                                       0.0004184100
# Not For Profit                             0.0004184100
# Notebookjs                                 0.0004184100
# Octave                                     0.0004184100
# Oculus                                     0.0004184100
# Omnichannel                                0.0004184100
# On Creandum                                0.0004184100
# Online Education                           0.0004184100
# Open Access                                0.0004184100
# Parallel Computing                         0.0004184100
# Paris                                      0.0004184100
# Payoff Science                             0.0004184100
# Peer Review                                0.0004184100
# People Analytics                           0.0004184100
# Performance                                0.0004184100
# Personal Growth                            0.0004184100
# PhD                                        0.0004184100
# Philippines                                0.0004184100
# Photography                                0.0004184100
# Pipeline                                   0.0004184100
# Police Brutality                           0.0004184100
# Politica                                   0.0004184100
# Política                                   0.0004184100
# Political Science                          0.0004184100
# Postgres                                   0.0004184100
# Predictive Marketing                       0.0004184100
# Pricing                                    0.0004184100
# Problem Solving                            0.0004184100
# Product Analytics                          0.0004184100
# Product Manager                            0.0004184100
# Product Updates                            0.0004184100
# Projects                                   0.0004184100
# Prototyping                                0.0004184100
# Psychohistory                              0.0004184100
# Public Relations                           0.0004184100
# Public Service                             0.0004184100
# Public Transport                           0.0004184100
# Puzzle                                     0.0004184100
# Pydata                                     0.0004184100
# Pyspark                                    0.0004184100
# Python3                                    0.0004184100
# Quora                                      0.0004184100
# Random Thoughts                            0.0004184100
# React                                      0.0004184100
# Reading                                    0.0004184100
# Reasoning                                  0.0004184100
# Recommendation Engine                      0.0004184100
# Reporting                                  0.0004184100
# Ruby on Rails                              0.0004184100
# Sales Development                          0.0004184100
# Sas                                        0.0004184100
# Sas Training                               0.0004184100
# Satalia University                         0.0004184100
# ...
# Samu                                       0.0002092050
# Sas Classes                                0.0002092050
# Sas Training Academy                       0.0002092050
# Sas Training Classes                       0.0002092050
# Satellite Imagery                          0.0002092050
# Scientific Software                        0.0002092050
# Scientist                                  0.0002092050
# Scipy                                      0.0002092050
# Scrum                                      0.0002092050
# Seattle                                    0.0002092050
# Secrets                                    0.0002092050
# Self Taught                                0.0002092050
# Semanticweb                                0.0002092050
# Semiology                                  0.0002092050
# Semiotics                                  0.0002092050
# Senior Care                                0.0002092050
# Sensor                                     0.0002092050
# Sep                                        0.0002092050
# Serp                                       0.0002092050
# Server                                     0.0002092050
# Sf Rent                                    0.0002092050
# Sharks                                     0.0002092050
# Sherlock Holmes                            0.0002092050
# Shopping Cart Solutions                    0.0002092050
# Short Story                                0.0002092050
# Shows                                      0.0002092050
# Signals Use Case                           0.0002092050
# Silicon Milkroundabout                     0.0002092050
# Simulation                                 0.0002092050
# Skiing                                     0.0002092050
# Skills Development                         0.0002092050
# Slidebot                                   0.0002092050
# Small Business Marketing                   0.0002092050
# Small Businesses                           0.0002092050
# Small Data                                 0.0002092050
# Smart Grid                                 0.0002092050
# Smarthome                                  0.0002092050
# Smartup Indonesia                          0.0002092050
# Snowplow                                   0.0002092050
# Social Analytics                           0.0002092050
# Social Enterprise                          0.0002092050
# Social Experiment                          0.0002092050
# Social Graph                               0.0002092050
# Social Justice                             0.0002092050
# Social Marketing                           0.0002092050
# Social Networking                          0.0002092050
# Social Work                                0.0002092050
# Socialgood                                 0.0002092050
# Softbcom Berlin                            0.0002092050
# Software Architecture                      0.0002092050
# Solving Hard Problems                      0.0002092050
# Som                                        0.0002092050
# Sound                                      0.0002092050
# Soundscape                                 0.0002092050
# South Africa                               0.0002092050
# Spacenet                                   0.0002092050
# Spam                                       0.0002092050
# Spc                                        0.0002092050
# Speaking Events                            0.0002092050
# Speech Recognition                         0.0002092050
# Spherical                                  0.0002092050
# Split Testing                              0.0002092050
# Sport                                      0.0002092050
# Sport Analytics                            0.0002092050
# Sports Illustrated                         0.0002092050
# Spss                                       0.0002092050
# Sql Azure                                  0.0002092050
# Sql Server                                 0.0002092050
# Square                                     0.0002092050
# Sre                                        0.0002092050
# Ssis Online Classes                        0.0002092050
# Ssis Online Training                       0.0002092050
# Ssis Training                              0.0002092050
# Stalking                                   0.0002092050
# Stanford                                   0.0002092050
# Stantonfilm                                0.0002092050
# Star Trek                                  0.0002092050
# Start Up                                   0.0002092050
# Startup Lessons                            0.0002092050
# Startup Ummah                              0.0002092050
# Stata                                      0.0002092050
# State Capture                              0.0002092050
# Statistical Significance                   0.0002092050
# Statistical Test                           0.0002092050
# STEM                                       0.0002092050
# Stem Education                             0.0002092050
# Steowise                                   0.0002092050
# Stock Photos                               0.0002092050
# Storyboarding                              0.0002092050
# Strava                                     0.0002092050
# Streaming Analytics                        0.0002092050
# Students                                   0.0002092050
# Subscription Economy                       0.0002092050
# Subway                                     0.0002092050
# Success                                    0.0002092050
# SugarCRM                                   0.0002092050
# Suicide                                    0.0002092050
# Summer                                     0.0002092050
# Suntech Applications                       0.0002092050
# Supercollider                              0.0002092050
# Superheroes                                0.0002092050
# Supervised Learning                        0.0002092050
# Supervisedlearning                         0.0002092050
# Support                                    0.0002092050
# Support Vector Machine                     0.0002092050
# Surprise De La Barmaid                     0.0002092050
# Survey Research                            0.0002092050
# Surveys                                    0.0002092050
# Sustainability                             0.0002092050
# Svm                                        0.0002092050
# Svr                                        0.0002092050
# Swimsuit                                   0.0002092050
# Swirl                                      0.0002092050
# Sydney                                     0.0002092050
# Syracuse                                   0.0002092050
# Systems                                    0.0002092050
# T Test                                     0.0002092050
# Tablab                                     0.0002092050
# Take Five Primer                           0.0002092050
# Talent Acquisition                         0.0002092050
# Talent Mapping                             0.0002092050
# Talent Pipelining                          0.0002092050
# Talentdash                                 0.0002092050
# Tanzania                                   0.0002092050
# Target Market                              0.0002092050
# Tattoo                                     0.0002092050
# Taxes                                      0.0002092050
# Taxi                                       0.0002092050
# Taxonomy                                   0.0002092050
# Tech Bootcamp                              0.0002092050
# Tech Jobs                                  0.0002092050
# Tech Talk                                  0.0002092050
# Techcity                                   0.0002092050
# Technology For Businesses                  0.0002092050
# Technology Studies                         0.0002092050
# Ted                                        0.0002092050
# Tedtalks                                   0.0002092050
# Telemedicine                               0.0002092050
# Teradata                                   0.0002092050
# Terminal                                   0.0002092050
# Terminator                                 0.0002092050
# Terminology                                0.0002092050
# Terragon Tech                              0.0002092050
# Test Automation                            0.0002092050
# Test Data                                  0.0002092050
# Text                                       0.0002092050
# Text Analysis                              0.0002092050
# Textbooks                                  0.0002092050
# Textio                                     0.0002092050
# Thailand                                   0.0002092050
# The A Team                                 0.0002092050
# The Blog                                   0.0002092050
# The Economist                              0.0002092050
# The New York Times                         0.0002092050
# The Reliants Project                       0.0002092050
# The Tips                                   0.0002092050
# Theatre                                    0.0002092050
# Theory                                     0.0002092050
# Thought Leadership                         0.0002092050
# Tidyverse                                  0.0002092050
# Time Segmentation                          0.0002092050
# Timeseries Forecasting                     0.0002092050
# Tinder                                     0.0002092050
# Tips                                       0.0002092050
# Tokyo                                      0.0002092050
# Toronto                                    0.0002092050
# Trabalhador                                0.0002092050
# Trabalho                                   0.0002092050
# Tradeshift                                 0.0002092050
# Trading                                    0.0002092050
# Traffic Safety                             0.0002092050
# Train                                      0.0002092050
# Transcript                                 0.0002092050
# Transgender                                0.0002092050
# Translation                                0.0002092050
# Transparency                               0.0002092050
# Travel Writing                             0.0002092050
# Treehouse                                  0.0002092050
# Trending                                   0.0002092050
# Trending Events                            0.0002092050
# Tripadvisor                                0.0002092050
# Trump Transition                           0.0002092050
# Truth                                      0.0002092050
# Tsne                                       0.0002092050
# Turkce                                     0.0002092050
# Turkey                                     0.0002092050
# Tutorials                                  0.0002092050
# Twitter Data                               0.0002092050
# Types Of Evidence                          0.0002092050
# Typography                                 0.0002092050
# Uae                                        0.0002092050
# Ubuntu                                     0.0002092050
# UI                                         0.0002092050
# UI Design                                  0.0002092050
# Ui Ux                                      0.0002092050
# UK                                         0.0002092050
# UK Politics                                0.0002092050
# Uncertainty                                0.0002092050
# Uniper                                     0.0002092050
# Unstructured Data                          0.0002092050
# Urbanism                                   0.0002092050
# US Elections                               0.0002092050
# USA                                        0.0002092050
# Usability                                  0.0002092050
# Usability Testing                          0.0002092050
# Usain Bolt                                 0.0002092050
# Use Cases                                  0.0002092050
# User Onboarding                            0.0002092050
# Utah                                       0.0002092050
# Utilities                                  0.0002092050
# UX Design                                  0.0002092050
# Value Based Care                           0.0002092050
# Variance                                   0.0002092050
# Vaxxed                                     0.0002092050
# VC                                         0.0002092050
# Vendas Para O Governo                      0.0002092050
# Vibration Analysis                         0.0002092050
# Video Conferencing                         0.0002092050
# Videogames                                 0.0002092050
# Videos                                     0.0002092050
# Violate                                    0.0002092050
# Viral                                      0.0002092050
# Virtual Assistant                          0.0002092050
# Vision                                     0.0002092050
# Visual Thinking                            0.0002092050
# Visualization Analytics                    0.0002092050
# Voting                                     0.0002092050
# VR                                         0.0002092050
# War                                        0.0002092050
# Wealth Inequality                          0.0002092050
# Web                                        0.0002092050
# Web Scraping Service                       0.0002092050
# Web Series                                 0.0002092050
# Web Spider                                 0.0002092050
# WebRTC                                     0.0002092050
# Weightlifting                              0.0002092050
# Wellbeing                                  0.0002092050
# Wellesley                                  0.0002092050
# West Nile Virus                            0.0002092050
# Wethe5th                                   0.0002092050
# What Is Data Science                       0.0002092050
# White House                                0.0002092050
# White Privilege                            0.0002092050
# Who I Am                                   0.0002092050
# Wikimedia                                  0.0002092050
# Wildlife                                   0.0002092050
# Windowing                                  0.0002092050
# Windows                                    0.0002092050
# Wired                                      0.0002092050
# Wisdom                                     0.0002092050
# Wogrammer                                  0.0002092050
# Women In Data Science                      0.0002092050
# Women in STEM                              0.0002092050
# Women Tech Organizations                   0.0002092050
# WordPress                                  0.0002092050
# Work Bench Investments                     0.0002092050
# Work Culture                               0.0002092050
# Work Life Balance                          0.0002092050
# Workers Compensation                       0.0002092050
# Workflow                                   0.0002092050
# Working Parents                            0.0002092050
# Workload Distribution                      0.0002092050
# Workplace                                  0.0002092050
# Worl                                       0.0002092050
# World Series                               0.0002092050
# Wow                                        0.0002092050
# Wroclaw                                    0.0002092050
# Wso2                                       0.0002092050
# Wwii                                       0.0002092050
# Ycombinator                                0.0002092050
# Year In Review                             0.0002092050
# Yoctol                                     0.0002092050
# YouTube                                    0.0002092050
# Yt Project                                 0.0002092050
# Z Test                                     0.0002092050
# Zeppelin                                   0.0002092050
# Zika Virus                                 0.0002092050
# Zodiac                                     0.0002092050
# Образование                                0.0002092050
# Технологии                                 0.0002092050
# Украина                                    0.0002092050
# 데이터사이언티스트                         0.0002092050
# 엘리스                                     0.0002092050
# 大数据                                     0.0002092050
# 数据工程师                                 0.0002092050
# 日本語                                     0.0002092050

# %%
# %%R
#
# itemsets <- apriori(tr, parameter = list(supp=0.001, conf=0.8, target='frequent', minlen=3))
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#          NA    0.1    1 none FALSE            TRUE       5   0.001      3
#  maxlen            target   ext
#      10 frequent itemsets FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 4
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[2363 item(s), 4780 transaction(s)] done [0.01s].
# sorting and recoding items ... [365 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [69 set(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
# %%R
#
# quality(itemsets)$lift <- interestMeasure(itemsets, measure='lift', tr)
#
# inspect(sort(itemsets, by ='count', decreasing = T))
# Out:
#      items                         support count         lift
# [1]  {Artificial Intelligence,
#       Big Data,
#       Machine Learning}        0.015899582    76    3.2891744
# [2]  {Artificial Intelligence,
#       Deep Learning,
#       Machine Learning}        0.007740586    37   25.4120714
# [3]  {Big Data,
#       Deep Learning,
#       Machine Learning}        0.005020921    24    3.8047544
# [4]  {Analytics,
#       Big Data,
#       Data}                    0.004184100    20    3.2183914
# [5]  {Artificial Intelligence,
#       Big Data,
#       Deep Learning}           0.003765690    18    9.0856858
# [6]  {Big Data,
#       Data,
#       Machine Learning}        0.003556485    17    1.0733470
# [7]  {Artificial Intelligence,
#       Big Data,
#       Deep Learning,
#       Machine Learning}        0.003347280    16   35.9776975
# [8]  {Artificial Intelligence,
#       Machine Learning,
#       Tech}                    0.003138075    15    6.6746590
# [9]  {Big Data,
#       Data,
#       Data Visualization}      0.002510460    12    1.7079111
# [10] {Analytics,
#       Big Data,
#       Machine Learning}        0.002510460    12    0.4157214
# [11] {Analytics,
#       Big Data,
#       Business Intelligence}   0.002092050    10    6.3004103
# [12] {Artificial Intelligence,
#       Machine Learning,
#       Software Development}    0.002092050    10   10.5311287
# [13] {Big Data,
#       Data Visualization,
#       Design}                  0.002092050    10    4.6306039
# [14] {AI,
#       Big Data,
#       Machine Learning}        0.001882845     9    4.2343235
# [15] {Big Data,
#       Data,
#       Open Data}               0.001882845     9    6.1588308
# [16] {Artificial Intelligence,
#       Machine Learning,
#       Startup}                 0.001882845     9    2.7340430
# [17] {Big Data,
#       Data Analysis,
#       Data Management}         0.001673640     8   53.7094433
# [18] {2016 Election,
#       Donald Trump,
#       Politics}                0.001673640     8 1566.5818185
# [19] {Artificial Intelligence,
#       Data,
#       Machine Learning}        0.001673640     8    2.1882865
# [20] {Artificial Intelligence,
#       Big Data,
#       Data}                    0.001673640     8    1.6082407
# [21] {Artificial Intelligence,
#       Big Data,
#       Data,
#       Machine Learning}        0.001673640     8    7.1643900
# [22] {Deep Learning,
#       Machine Learning,
#       TensorFlow}              0.001464435     7   85.2732240
# [23] {Big Data,
#       Data Mining,
#       Machine Learning}        0.001464435     7    2.4901035
# [24] {Big Data,
#       Business Intelligence,
#       Data Analysis}           0.001464435     7   16.7273054
# [25] {Big Data,
#       Machine Learning,
#       Software Development}    0.001464435     7    1.7015707
# [26] {Analytics,
#       Big Data,
#       Marketing}               0.001464435     7    2.7390205
# [27] {Artificial Intelligence,
#       Big Data,
#       Tech}                    0.001464435     7    2.2891947
# [28] {Big Data,
#       Machine Learning,
#       Tech}                    0.001464435     7    0.7189735
# [29] {Artificial Intelligence,
#       Machine Learning,
#       Python}                  0.001464435     7    2.0765606
# [30] {Big Data,
#       Machine Learning,
#       Startup}                 0.001464435     7    0.4908377
# [31] {Artificial Intelligence,
#       Big Data,
#       Machine Learning,
#       Tech}                    0.001464435     7   10.1979037
# [32] {Artificial Intelligence,
#       Machine Learning,
#       TensorFlow}              0.001255230     6   19.9537175
# [33] {Big Data,
#       Entrepreneurship,
#       Startup}                 0.001255230     6   12.5397348
# [34] {AI,
#       Artificial Intelligence,
#       Machine Learning}        0.001255230     6   12.2296978
# [35] {Big Data,
#       Government,
#       Open Data}               0.001255230     6   28.7412104
# [36] {Big Data,
#       Data Visualization,
#       Rstats}                  0.001255230     6    3.7219571
# [37] {Big Data,
#       Business Intelligence,
#       Predictive Analytics}    0.001255230     6   28.4193506
# [38] {2016 Election,
#       Big Data,
#       Politics}                0.001255230     6   18.5092715
# [39] {Big Data,
#       Big Data Analytics,
#       Data}                    0.001255230     6    6.8895395
# [40] {Big Data,
#       Business,
#       Machine Learning}        0.001255230     6    1.3890373
# [41] {Analytics,
#       Big Data,
#       Data Analysis}           0.001255230     6    2.0093200
# [42] {Big Data,
#       Tech,
#       Technology}              0.001255230     6    5.7500021
# [43] {Artificial Intelligence,
#       Machine Learning,
#       Technology}              0.001255230     6    3.2967012
# [44] {Analytics,
#       Big Data,
#       Technology}              0.001255230     6    1.9394306
# [45] {Artificial Intelligence,
#       Machine Learning,
#       Programming}             0.001255230     6    2.7472510
# [46] {Big Data,
#       Machine Learning,
#       Programming}             0.001255230     6    0.6341257
# [47] {Artificial Intelligence,
#       Machine Learning,
#       Statistics}              0.001255230     6    2.2170797
# [48] {Analytics,
#       Machine Learning,
#       Python}                  0.001255230     6    1.4247728
# [49] {Analytics,
#       Big Data,
#       Startup}                 0.001255230     6    1.0722814
# [50] {Artificial Intelligence,
#       Human In The Loop,
#       Machine Learning}        0.001046025     5   63.1867722
# [51] {Big Data,
#       Bpo,
#       Outsourcing}             0.001046025     5 1016.2070806
# [52] {Data Analysis,
#       Data Analytics,
#       Python Data Analysis}    0.001046025     5 4084.1555842
# [53] {Big Data,
#       Business,
#       Outsourcing}             0.001046025     5  112.9118978
# [54] {R,
#       Rstats,
#       Rstudio}                 0.001046025     5 2524.0157306
# [55] {2016 Election,
#       Donald Trump,
#       Hillary Clinton}         0.001046025     5 7261.7594711
# [56] {Deep Learning,
#       Machine Learning,
#       Neural Networks}         0.001046025     5   64.2933038
# [57] {Artificial Intelligence,
#       Machine Learning,
#       Neural Networks}         0.001046025     5   17.5518812
# [58] {Artificial Intelligence,
#       Machine Learning,
#       Towards Data Science}    0.001046025     5   17.5518812
# [59] {Big Data,
#       Business,
#       IoT}                     0.001046025     5   33.5684021
# [60] {Big Data,
#       IoT,
#       Machine Learning}        0.001046025     5    1.9709313
# [61] {Big Data,
#       Big Data Analytics,
#       Hadoop}                  0.001046025     5   30.8427060
# [62] {Analytics,
#       Big Data,
#       Data Engineering}        0.001046025     5    4.5332220
# [63] {Analytics,
#       Big Data,
#       Predictive Analytics}    0.001046025     5    3.3189661
# [64] {Artificial Intelligence,
#       Big Data,
#       Software Development}    0.001046025     5    3.8698291
# [65] {Big Data,
#       Machine Learning,
#       Marketing}               0.001046025     5    0.7676259
# [66] {Big Data,
#       Data Analysis,
#       Machine Learning}        0.001046025     5    0.6569771
# [67] {Big Data,
#       Machine Learning,
#       Python}                  0.001046025     5    0.3423684
# [68] {Analytics,
#       Artificial Intelligence,
#       Big Data}                0.001046025     5    0.5515196
# [69] {Artificial Intelligence,
#       Big Data,
#       Machine Learning,
#       Software Development}    0.001046025     5   17.2393134
